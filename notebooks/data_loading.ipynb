# %%
import pandas as pd

# %%
import sys
import os

# Add the project root directory (go up one level from notebooks)
sys.path.append(os.path.abspath(".."))

# %%
# Calling function from data_loading.py file

from scripts.data_loading import load_data

# %%
import os
print(os.getcwd())
# Out:
# /Users/sawlehaanwaar/life_expectancy_prediction_ml_model/notebooks

# %%
data_source = '../data/raw/life_expectancy_data.csv'

# %%
# Load data and view header
df = load_data(data_source)

df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
def load_and_preprocess_data(file_path, text_variables, num_variables, target_variable):

    df = pd.read_csv(file_path)

    df.columns = df.columns.str.strip().str.replace('  ', ' ')

    print("Cleaned Column Names:\n", df.columns)
    
    X = df[text_variables + num_variables]  
    y = df[target_variable]
    
    return X, y

# %%
# Hyperparameters and settings
data_source = '/Users/sawlehaanwaar/Downloads/Life Expectancy Data.csv'
text_variables = ['Country', 'Status']
num_variables = ['Year', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles',
                 'BMI', 'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria', 'HIV/AIDS', 'GDP',
                 'thinness  1-19 years', 'thinness 5-9 years', 'Income composition of resources', 'Schooling']
target_variable = 'Life expectancy'

# Hyperparameters for model
LASSO_ALPHA = 0.0001
RANDOM_STATE = 42

# %%
X, y = load_and_preprocess_data(data_source, text_variables, num_variables, target_variable)
# Out:
# Cleaned Column Names:
#  Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness 1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 X, y = load_and_preprocess_data(data_source, text_variables, num_variables, target_variable)
#
# Cell In[27], line 9, in load_and_preprocess_data(file_path, text_variables, num_variables, target_variable)
#       5 df.columns = df.columns.str.strip().str.replace('  ', ' ')
#       7 print("Cleaned Column Names:\n", df.columns)
# ...
