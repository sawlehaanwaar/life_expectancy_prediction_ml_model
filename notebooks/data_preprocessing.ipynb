# %% [raw]
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import LabelEncoder, RobustScaler
# from sklearn.impute import SimpleImputer
# from scipy.stats import mstats

# %%
# Adding the project root to the Python path
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
# Importing the preprocessing function from .py file
from scripts.data_preprocessing_script import preprocess_data

# %%
# Defining the path to dataset
data_source = '../data/raw/life_expectancy_data.csv'

# %%
# Running the preprocessing pipeline
df_processed = preprocess_data(data_source)

# %%
df_processed.head()
# Out:
#     country   year  life expectancy  adult mortality  infant deaths  alcohol  \
# 0 -0.929293  0.875        -0.564516         0.777778       1.309470  -1.1592
# 1 -0.929293  0.750        -0.975806         0.830065       1.336331  -1.1592
# 2 -0.929293  0.625        -0.975806         0.810458       1.362776  -1.1592
# 3 -0.929293  0.500        -1.008065         0.836601       1.401704  -1.1592
# 4 -0.929293  0.375        -1.032258         0.856209       1.427187  -1.1592
#
#    percentage expenditure  hepatitis b   measles       bmi  ...  \
# 0                0.021175     0.634353  0.706586 -0.651226  ...
# 1                0.028196     0.687027  0.562034 -0.664850  ...
# 2                0.027256     0.652397  0.539214 -0.678474  ...
# 3                0.042126     0.596666  0.856211 -0.692098  ...
# 4               -0.481516     0.576956  0.869445 -0.702997  ...
#
#    total expenditure  diphtheria  hiv/aids       gdp  population  \
# 0           0.750612   -1.473684       0.0 -0.524765    1.333942
# 1           0.757368   -1.631579       0.0 -0.502244   -0.603004
# 2           0.740477   -1.526316       0.0 -0.487734    1.308338
# 3           0.872233   -1.368421       0.0 -0.459899    0.409865
# 4           0.652639   -1.315789       0.0 -1.571340    0.319568
#
#    thinness 1-19 years  thinness 5-9 years  income composition of resources  \
# 0             2.509091            2.482143                        -0.683473
# 1             2.563636            2.517857                        -0.694678
# 2             2.600000            2.553571                        -0.717087
# 3             2.636364            2.607143                        -0.743231
# 4             2.690909            2.642857                        -0.776844
#
#    schooling  status_Developing
# 0  -0.526316                0.0
# 1  -0.552632                0.0
# 2  -0.578947                0.0
# 3  -0.605263                0.0
# 4  -0.684211                0.0
#
# [5 rows x 22 columns]
